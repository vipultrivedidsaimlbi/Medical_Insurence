# %%
Git is a widely used Version Control System (VCS) 
that lets you keep track of all the modifications you make to your code

# %% [markdown]
# # Git working
# ************************************************************

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # JIRA

# %%
epic  >> 3 months >>project plan
sprint1 >> 15 days or 2 weeks
story1 >> EDA
       issues >> outliers dectection
story2 >> Feature engineering
       >> Model Building

# %% [markdown]
# # Git

# %%
1.GitHub
2.GitLab
3.BitBucket

# %% [markdown]
# # cloud

# %%
AWS
Azure
GCP

# %% [markdown]
# # Clone repo

# %%
Cloning means creating a copy of the remote repo on your local machine. 
Now you can make changes to the project on your local machine

# %%
git clone url

# %% [markdown]
# # Add your files

# %%
git add file_name
git add interface.py

git add --all
git add .

# %% [markdown]
# # commit your message

# %%
>> When you commit a change, you save the changes you made to your files in the repo. 
>> When working with Git from your local machine, using the commit command will save 
   your files in the local repo. 
>>To make those changes in the remote repo, you will use the push command

# %%
git commit -m "Your msg"

# %% [markdown]
# # Push

# %%
Push command allows you to transfer all the changes on your local repo to the remote repo. 
Now all the fellow developers will have access to the changes you made and 
they can update their local repositories

# %%
git push

git push origin branch name
